# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.api import VAR, DynamicVAR
# %matplotlib inline
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# Стационарность рядов???

# %%
m_train_data = pd.read_csv('montly_train_data_for_metamodel_07_2012_09_2014.csv')
q_train_data = pd.read_csv('quarter_train_data_for_metamodel_07_2012_09_2014.csv')
m_test_data = pd.read_csv('monthly_test_data_for_metamodel_10_2014_09_2015_no_target.csv')
q_test_data = pd.read_csv('quarter_test_data_for_metamodel_10_2014_09_2015_no_target.csv')

# %%
#data = np.log(mdata).diff().dropna()
data = q_train_data
dates = data[['REPORT_YEAR', 'REPORT_QUARTER']].astype(int).astype(str)
quarterly = dates["REPORT_YEAR"] + "Q" + dates["REPORT_QUARTER"]
from statsmodels.tsa.base.datetools import dates_from_str
quarterly = dates_from_str(quarterly)
data.index = pd.DatetimeIndex(quarterly)
data
# Out:
#             REPORT_QUARTER  REPORT_YEAR      GINI  MEAN_SCR__FEATURE_95  \
# 2013-03-31               1         2013  0.725818             20.329928
# 2014-03-31               1         2014  0.696211             20.569021
# 2013-06-30               2         2013  0.730679             20.432251
# 2014-06-30               2         2014  0.674392             20.664917
# 2012-09-30               3         2012  0.693014             20.345401
# 2013-09-30               3         2013  0.709539             20.467239
# 2014-09-30               3         2014  0.665402             20.785730
# 2012-12-31               4         2012  0.731426             20.298876
# 2013-12-31               4         2013  0.696011             20.553862
# 2013-03-31               1         2013  0.727975             20.329928
# 2014-03-31               1         2014  0.703165             20.569021
# 2013-06-30               2         2013  0.733381             20.432251
# ...

# %%
var_models, var_results = {}, {}
for i in data['QUARTERS_TO_DEFAULT_HORIZON'].unique():
    var_models[i] = VAR(data[data['QUARTERS_TO_DEFAULT_HORIZON'] == i])
    #print(data[data['QUARTERS_TO_DEFAULT_HORIZON'] == i])

# %%
for model in var_models.keys():
    print(type(model))
    var_results[model] = var_models[model].fit(1)
# Out:
# 9.0
# C:\ProgramData\Miniconda3\lib\site-packages\numpy\core\fromnumeric.py:52: RuntimeWarning: invalid value encountered in reduce
#   return getattr(obj, method)(*args, **kwds)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-25f8844e7781> in <module>()
#       1 for model in var_models.keys():
#       2     print(model)
# ----> 3     var_results[model] = var_models[model].fit(1)
#
# C:\ProgramData\Miniconda3\lib\site-packages\statsmodels\tsa\vector_ar\var_model.py in fit(self, maxlags, method, ic, trend, verbose)
#     436         self.nobs = len(self.endog) - lags
#     437
# --> 438         return self._estimate_var(lags, trend=trend)
#     439
#     440     def _estimate_var(self, lags, offset=0, trend='c'):
#
# C:\ProgramData\Miniconda3\lib\site-packages\statsmodels\tsa\vector_ar\var_model.py in _estimate_var(self, lags, offset, trend)
# ...

# %%
var_models[9.0] = var_models[9.0].fit(1)
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\numpy\core\fromnumeric.py:52: RuntimeWarning: invalid value encountered in reduce
#   return getattr(obj, method)(*args, **kwds)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-731fd525b5fe> in <module>()
# ----> 1 var_models[9.0] = var_models[9.0].fit(1)
#
# C:\ProgramData\Miniconda3\lib\site-packages\statsmodels\tsa\vector_ar\var_model.py in fit(self, maxlags, method, ic, trend, verbose)
#     436         self.nobs = len(self.endog) - lags
#     437
# --> 438         return self._estimate_var(lags, trend=trend)
#     439
#     440     def _estimate_var(self, lags, offset=0, trend='c'):
#
# C:\ProgramData\Miniconda3\lib\site-packages\statsmodels\tsa\vector_ar\var_model.py in _estimate_var(self, lags, offset, trend)
#     455         y = self.y[offset:]
#     456
# ...

# %%
prob = 0
for i in range(53,101):
    prob+=

# %%
# Out:
# range(53, 100)
